# %%
from speech_command_detection.utils import load_parquet_file, plot_confusion_matrix
from speech_command_detection.hmm import HMM

# %%
hmms = HMM.load("../models/HMMModels.pkl")

# %%
validation_df = load_parquet_file("../data/validation_features.parquet")

# %%
conf_matrix_df = hmms.evaluate(validation_df)
# Out:
# Evaluating data for label "zero": 100%|██████████| 30/30 [04:21<00:00,  8.70s/it]

# %%
plot_confusion_matrix(conf_matrix_df=conf_matrix_df)
